# %%
import pandas as pd
message = pd.read_csv('Data/SMSSpamCollection.txt',sep='\t',names=['label','message'])

# %%
message.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
import nltk
import re
from nltk.corpus import stopwords

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()

# %%
corpus = []
for i in range(len(message)):
    review = re.sub('[^a-zA-z]',' ',message['message'][i])
    review = review.lower().split()
    review = [ps.stem(word) for word in review if word not in set(stopwords.words('english'))]
    review = ' '.join(review)
    corpus.append(review)

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=100, ngram_range=(2,3))
X = cv.fit_transform(corpus).toarray()

# %%
cv.vocabulary_ # 'words' : (index in feature vector)
# Out:
# {'free entri': np.int64(31),
#  'claim call': np.int64(16),
#  'call claim': np.int64(2),
#  'free call': np.int64(30),
#  'chanc win': np.int64(15),
#  'txt word': np.int64(91),
#  'let know': np.int64(54),
#  'go home': np.int64(34),
#  'pleas call': np.int64(70),
#  'lt gt': np.int64(60),
#  'miss call': np.int64(62),
#  'want go': np.int64(97),
#  'like lt': np.int64(55),
#  'like lt gt': np.int64(56),
#  'sorri call': np.int64(83),
#  'call later': np.int64(10),
#  'sorri call later': np.int64(84),
#  'ur award': np.int64(92),
#  'hi hi': np.int64(46),
#  'call custom': np.int64(3),
#  'custom servic': np.int64(23),
#  'cash prize': np.int64(14),
#  'call custom servic': np.int64(4),
#  'po box': np.int64(71),
#  'tri contact': np.int64(89),
#  'draw show': np.int64(27),
#  'show prize': np.int64(81),
#  'prize guarante': np.int64(75),
#  'guarante call': np.int64(41),
#  'valid hr': np.int64(95),
#  'draw show prize': np.int64(28),
#  'show prize guarante': np.int64(82),
#  'prize guarante call': np.int64(76),
#  'select receiv': np.int64(78),
#  'privat account': np.int64(72),
#  'account statement': np.int64(0),
#  'call identifi': np.int64(5),
#  'identifi code': np.int64(48),
#  'code expir': np.int64(20),
#  'privat account statement': np.int64(73),
#  'call identifi code': np.int64(6),
#  'identifi code expir': np.int64(49),
#  'urgent mobil': np.int64(94),
#  'call landlin': np.int64(9),
#  'wat time': np.int64(98),
#  'ur mob': np.int64(93),
#  'gud ni': np.int64(43),
#  'new year': np.int64(65),
#  'send stop': np.int64(80),
#  'get back': np.int64(33),
#  'co uk': np.int64(19),
#  'nice day': np.int64(66),
#  'lt decim': np.int64(58),
#  'decim gt': np.int64(25),
#  'lt decim gt': np.int64(59),
#  'good morn': np.int64(35),
#  'good night': np.int64(36),
#  'repli call': np.int64(77),
#  'last night': np.int64(53),
#  'pick phone': np.int64(68),
#  'pl send': np.int64(69),
#  'send messag': np.int64(79),
#  'great day': np.int64(37),
#  'suit land': np.int64(85),
#  'land row': np.int64(52),
#  'suit land row': np.int64(86),
#  'take care': np.int64(87),
#  'call mobileupd': np.int64(11),
#  'call optout': np.int64(12),
#  'gt min': np.int64(40),
#  'lt gt min': np.int64(61),
#  'txt stop': np.int64(90),
#  'date servic': np.int64(24),
#  'call land': np.int64(7),
#  'land line': np.int64(50),
#  'line claim': np.int64(57),
#  'claim valid': np.int64(17),
#  'guarante call land': np.int64(42),
#  'call land line': np.int64(8),
#  'land line claim': np.int64(51),
#  'claim valid hr': np.int64(18),
#  'gt lt': np.int64(38),
#  'gt lt gt': np.int64(39),
#  'hope good': np.int64(47),
#  'free text': np.int64(32),
#  'prize claim': np.int64(74),
#  'nd attempt': np.int64(64),
#  'ok lor': np.int64(67),
#  'want come': np.int64(96),
#  'everi week': np.int64(29),
#  'come home': np.int64(22),
#  'happi new': np.int64(44),
#  'happi new year': np.int64(45),
#  'nation rate': np.int64(63),
#  'week txt': np.int64(99),
#  'tell ur': np.int64(88),
#  'await collect': np.int64(1),
#  'dont know': np.int64(26),
#  'come back': np.int64(21),
#  'call per': np.int64(13)}
